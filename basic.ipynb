# %%
p=1
q=2
p+q
# Out:
# 3

# %%
a=1+2j
a.real
# Out:
# 1.0

# %%
a.imag
# Out:
# 2.0

# %%
2/3
# Out:
# 0.6666666666666666

# %%
a = 5
a %= 3
print(a)
# Out:
# 2

# %%
# ==, !=, >,<, >=, <= -> 비교연산자

# %%
# 문자열 자료형
# ', " 둘 다 가능
# 처음 인덱스는 [0]이며 끝 인덱스 [-1]

# %%
A = "now is better than never"
print(A[0])
# Out:
# n

# %%
s3 = """Hello Python"""
s3
# Out:
# 'Hello Python'

# %%
head = "Python"
tail = " is fun"
head + tail
# Out:
# 'Python is fun'

# %%
head *2
# Out:
# 'PythonPython'

# %%
print("=" * 5) # 가독성을 위해
# Out:
# =====

# %%
a = "Now is better than never"
a[0]
# Out:
# 'N'

# %%
a[4]
# Out:
# 'i'

# %%
a[-1]
# Out:
# 'r'

# %%
a[-2]
# Out:
# 'e'

# %%
a[0:3]
# Out:
# 'Now'

# %%
a[4:6]
# Out:
# 'is'

# %%
a[19:]
# Out:
# 'never'

# %%
a[:3]
# Out:
# 'Now'

# %%
a[:]
# Out:
# 'Now is better than never'

# %%
a[7:-11]
# Out:
# 'better'

# %%
a = "Python"
a.count('P')
# Out:
# 1

# %%
s4 = """"Hi"""""
s4
# Out:
# '"Hi'

# %%
a
# Out:
# 'Python'

# %%
a = 'Python'

# %%
a.find('y')
# Out:
# 1

# %%
a.find('p')
# Out:
# -1

# %%
a.index('y')
# Out:
# 1

# %%
a.index("P")
# Out:
# 0

# %%
b = ","
c = b.join("Abcd")
c
# Out:
# 'A,b,c,d'

# %%
a.upper()
# Out:
# 'PYTHON'

# %%
a.lower()
# Out:
# 'python'

# %%
a = 'Pithon'

# %%
a[1] = 'y' # replace를 이용해서 값을 바꾸어야 함
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-d5923cc78d10> in <module>
# ----> 1 a[1] = 'y'
#
# TypeError: 'str' object does not support item assignment

# %%
a = "Python is difficult."

# %%
a.replace("difficult", "funny")
# Out:
# 'Python is funny.'

# %%
a.split()
# Out:
# ['Python', 'is', 'difficult.']

# %%
b = "a, b, c, d"
b
# Out:
# 'a, b, c, d'

# %%
b.split(",")
# Out:
# ['a', ' b', ' c', ' d']

# %%
a = [1,2,3]
b = ['Life', 'is', 'too', 'short']
c = [1, 2, 'Life', 'is']
d = [1, 2, [3,4], ['Life', 'is']]

# %%
d[0]
# Out:
# 1

# %%
d[2]
# Out:
# [3, 4]

# %%
d[3]
# Out:
# ['Life', 'is']

# %%
d[3][-1]
# Out:
# 'is'

# %%
d[0:3]
# Out:
# [1, 2, [3, 4]]

# %%
a + b
# Out:
# [1, 2, 3, 'Life', 'is', 'too', 'short']

# %%
b[0] + " hi~ ^^;"
# Out:
# 'Life hi~ ^^;'

# %%
a[0] + " hi~ ^^;" # 정수형 + 문자형 연산 불가
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-3939a309e998> in <module>
# ----> 1 a[0] + " hi~ ^^;"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
a = [1,2,3]

# %%
a[2]=99
a
# Out:
# [1, 2, 99]

# %%
a[1:2] = ['a','b','c']
a
# Out:
# [1, 'a', 'b', 'c', 'b', 'c', 99]

# %%
a = [1,2,3]

# %%
a[2]=99
a
# Out:
# [1, 2, 99]

# %%
a[1:2] = ['a','b','c']
a
# Out:
# [1, 'a', 'b', 'c', 99]

# %%
a[-1] = ['d','e','f']
a
# Out:
# [1, 'a', 'b', 'c', ['d', 'e', 'f']]

# %%
del a[-1]
a
# Out:
# [1, 'a', 'b', 'c']

# %%
a.append(5)
a
# Out:
# [1, 'a', 'b', 'c', 5]

# %%
b
# Out:
# ['Life', 'is', 'too', 'short']

# %%
b.sort()

# %%
b
# Out:
# ['Life', 'is', 'short', 'too']

# %%
a = [3,4,1,9]
a
# Out:
# [3, 4, 1, 9]

# %%
a.reverse()
a
# Out:
# [9, 1, 4, 3]

# %%
a
# Out:
# [9, 1, 4, 3]

# %%
a.index(9)
# Out:
# 0

# %%
a.insert(0,99)

# %%
a
# Out:
# [99, 9, 1, 4, 3]

# %%
a.remove(99)

# %%
a
# Out:
# [9, 1, 4, 3]

# %%
b = [1,2,3]

# %%
b.pop()
# Out:
# 3

# %%
b
# Out:
# [1, 2]

# %%
b.pop(0)
# Out:
# 1

# %%
b
# Out:
# [2]

# %%
a = [2,1,0,2,3,2,4,2]

# %%
a.count(2)
# Out:
# 4
